# %%
import pandas as pd

# %%
# AQI Data Set

df = pd.read_csv("globalAirQuality.csv")

df.describe()
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 18000 entries, 0 to 17999
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   timestamp    18000 non-null  str
#  1   country      18000 non-null  str
#  2   city         18000 non-null  str
#  3   latitude     18000 non-null  float64
#  4   longitude    18000 non-null  float64
#  5   pm25         18000 non-null  float64
#  6   pm10         18000 non-null  float64
#  7   no2          18000 non-null  float64
#  8   so2          18000 non-null  float64
#  9   o3           18000 non-null  float64
#  10  co           18000 non-null  float64
#  11  aqi          18000 non-null  int64
#  12  temperature  18000 non-null  float64
#  13  humidity     18000 non-null  float64
#  14  wind_speed   18000 non-null  float64
# dtypes: float64(11), int64(1), str(3)
# memory usage: 2.1 MB

# %% [markdown]
# ## <center> Indexing and Selecting </center>

# %%
# selcting data


# for column

df["country"]
df["city"]
# for multiple columns
df[["city",'aqi']]

# for selecting row(loc & iloc) loc ->> location and iloc->> index location
df.loc[0]
df.loc[0:2]  # start idx : end idx(inclusive) --> means last index will also be print


df.iloc[2]
df.iloc[0:2] # start idx : end idx(exclusive)  --> means last index will nopt be print


#selecting rows & columns. df.loc[rows,columns]
df.loc[0, "aqi"]
df.loc[0,["city","aqi"]]

df.loc[0:2, ["country", "city", "latitude" , "longitude"]]
df.iloc[0:3, 1:5]

# single scalar value -at & iat
df.at[0,"city"]
df.iat[0,2]


cities = df["city"].copy() # view
cities[0] = "New York"  # copy

# %% [markdown]
# ## <center> Filtering </center>

# %%
# Filtering of data

df[ df["aqi"] > 100]

# multiple condition 
df[(df["aqi"] > 100)& (df["temperature"]> 30)]
df[(df["aqi"] > 100)& (df["temperature"]> 30)]

aqi_data = df[ (df["aqi"] > 100) & (df["temperature"] > 30)] [["city", "aqi"]] # two filter used 

aqi_data
aqi_data.iloc[0]
aqi_data.loc[6]


#Querry
df.query("aqi >100")

aqi_val = 100
df.query("aqi > 100 & temperature > 30")[["city", "aqi"]]
df.query("aqi > @aqi_val & temperature > 30")[["city", "aqi"]]
# Out:
#            city  aqi
# 6      New York  155
# 7      New York  115
# 14     New York  121
# 17     New York  127
# 25     New York  113
# ...         ...  ...
# 17947    Zurich  107
# 17950    Zurich  140
# 17975    Zurich  111
# 17976    Zurich  146
# 17991    Zurich  104
#
# [2384 rows x 2 columns]

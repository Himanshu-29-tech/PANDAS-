# %% [markdown]
# ## <center> Pandas </center>
#
# ---
# - Shift id column to the end
#
# ---

# %%
import pandas as pd

df = pd.read_csv("raw_data.csv")
df2 = df.copy()

new_col_ord = [col for col in df2.columns if col  != "ID"] +[ "ID"]
print(new_col_ord)

df2[new_col_ord]
# Out:
# ['Name', 'Age', 'Department', 'Salary', 'country', 'gender', 'ID']
#       Name  Age Department  Salary   country   gender  ID
# 0    Alice   25         HR   55000     'USA'   'Male'   1
# 1      Bob   32         IT   72000     'USA'   Female   2
# 2  Charlie   28    Finance   48000     'UAE'     Male   3
# 3    David   45  Marketing   91000     'UAE'  Unknown   4
# 4      Eva   38         IT   65000     'USA'   Female   5
# 5    Frank   29    Finance   50000  'FRENCH'     Male   6
# 6    Grace   41         HR   82000  'RUSSIA'   Female   7
# 7   Hannah   26  Marketing   47000   'INDIA'     Male   8
# 8      Ian   35         IT   75000   'JAPAN'     Male   9
# 9    Julia   30    Finance   60000   'CHINA'     Male  10
